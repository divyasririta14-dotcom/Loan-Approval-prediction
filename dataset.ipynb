# %%
# Step 1: Import Pandas
import pandas as pd

# Step 2: Create the dataset
data = {
    "Loan_ID": ["LP001", "LP002", "LP003", "LP004", "LP005",
                "LP006", "LP007", "LP008", "LP009", "LP010"],

    "Gender": ["Male", "Female", "Male", "Male", "Female",
               "Male", "Male", "Female", "Male", "Female"],

    "Married": ["Yes", "No", "Yes", "Yes", "No",
                "Yes", "No", "Yes", "Yes", "No"],

    "Dependents": ["0", "1", "2", "0", "0",
                   "1", "0", "2", "3+", "1"],

    "Education": ["Graduate", "Graduate", "Not Graduate", "Graduate",
                  "Graduate", "Graduate", "Not Graduate", "Graduate",
                  "Graduate", "Not Graduate"],

    "ApplicantIncome": [5000, 3500, 2800, 6200, 4200,
                        3000, 2400, 5200, 7000, 2600],

    "CoapplicantIncome": [1500, 0, 1200, 1800, 0,
                          1000, 0, 1300, 2000, 500],

    "LoanAmount": [120, 100, 90, 160, 110,
                   95, 75, 140, 190, 80],

    "Credit_History": [1, 1, 0, 1, 1,
                       1, 0, 1, 1, 0],

    "Property_Area": ["Urban", "Rural", "Semiurban", "Urban", "Semiurban",
                      "Rural", "Rural", "Urban", "Semiurban", "Rural"],

    "Loan_Status": ["Y", "Y", "N", "Y", "Y",
                    "Y", "N", "Y", "Y", "N"]
}

# Step 3: Create DataFrame
df = pd.DataFrame(data)

# Step 4: Display the DataFrame
df

print(df.head())
print(df.tail())
print(df.shape)
print(df.dtypes)
print(df.columns.tolist())
# Out:
#   Loan_ID  Gender Married Dependents     Education  ApplicantIncome  \
# 0   LP001    Male     Yes          0      Graduate             5000
# 1   LP002  Female      No          1      Graduate             3500
# 2   LP003    Male     Yes          2  Not Graduate             2800
# 3   LP004    Male     Yes          0      Graduate             6200
# 4   LP005  Female      No          0      Graduate             4200
#
#    CoapplicantIncome  LoanAmount  Credit_History Property_Area Loan_Status
# 0               1500         120               1         Urban           Y
# 1                  0         100               1         Rural           Y
# 2               1200          90               0     Semiurban           N
# 3               1800         160               1         Urban           Y
# 4                  0         110               1     Semiurban           Y
#   Loan_ID  Gender Married Dependents     Education  ApplicantIncome  \
# ...
